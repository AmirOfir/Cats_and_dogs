# %% [markdown]
# #Tryout #5
# Dropped learning data size to 9000 each class

# %%
import sys
import numpy as np
import torch
import torch.nn as nn
#from torch.autograd import Function
from torchvision import transforms, datasets
# import math

import torch.nn.functional as F
# import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, ConcatDataset
# import copy
import tqdm
from PIL import Image

# Load the data (extract)
import os
import zipfile
from pathlib import Path
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
if not (os.path.exists('tmp/train')):
  local_zip = '/content/drive/My Drive/datasets/dogscats/train.zip'
  zip_ref = zipfile.ZipFile(local_zip, 'r')
  zip_ref.extractall('/tmp')
  zip_ref.close()
  local_zip = '/content/drive/My Drive/datasets/dogscats/test.zip'
  zip_ref = zipfile.ZipFile(local_zip, 'r')
  zip_ref.extractall('/tmp')
  zip_ref.close()
import gc
gc.collect()

base_dir = '/tmp'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'test1')

train_fnames = os.listdir(train_dir)
validation_fnames = os.listdir(validation_dir)

train_cat_fnames = [os.path.join(train_dir, x) for x in train_fnames if x.startswith('cat')][:-3500]
train_dog_fnames = [os.path.join(train_dir, x) for x in train_fnames if x.startswith('dog')][:-3500]
validation_cat_fnames = [os.path.join(train_dir, x) for x in train_fnames if x.startswith('cat')][-500:]
validation_dog_fnames = [os.path.join(train_dir, x) for x in train_fnames if x.startswith('dog')][-500:]

del train_fnames
del validation_fnames
print('total training cat images:', len(train_cat_fnames))
print('total training dog images:', len(train_dog_fnames))
print('total validation cat images:', len(validation_cat_fnames))
print('total validation dog images:', len(validation_dog_fnames))
# Out:
# total training cat images: 9000
# total training dog images: 9000
# total validation cat images: 500
# total validation dog images: 500

# %%
class CatDogDataset(Dataset):
    def __init__(self, file_list, label=-1, mode='train', transform = None):
        self.file_list = file_list
        self.label = label
        self.mode = mode
        self.transform = transform
        
    def __len__(self):
        return len(self.file_list)
    
    def __getitem__(self, idx):
        img = Image.open(self.file_list[idx])
        img
        if self.transform:
            img = self.transform(img)
            
        if self.mode == 'train':
            img = img.numpy()
            return img.astype('float32'), self.label
        else:
            img = img.numpy()
            return img.astype('float32'), self.label #file_list[idx]
        
data_transform = transforms.Compose([
    transforms.Resize((45,45)),
    transforms.Resize((450,450)),
    transforms.Grayscale(),
    transforms.ToTensor()
])

train_cats_ds = CatDogDataset(train_cat_fnames, 0, transform = data_transform)
train_dogs_ds = CatDogDataset(train_dog_fnames, 1, transform = data_transform)

train_catdogs_ds = ConcatDataset([train_cats_ds, train_dogs_ds])
dataloader = DataLoader(train_catdogs_ds, batch_size = 32, shuffle=True, num_workers=0)

validation_cats = CatDogDataset(validation_cat_fnames, 0, transform = data_transform)
validation_dogs = CatDogDataset(validation_dog_fnames, 1, transform = data_transform)

validation_catdogs = ConcatDataset([validation_cats, validation_dogs])
validation_size = len(validation_cat_fnames) + len(validation_dog_fnames)
validation_dataloader = DataLoader(validation_catdogs, batch_size = int(validation_size / 100), shuffle=False, num_workers=0)

# %%
samples, labels = iter(dataloader).next()
print(samples.shape)
del samples
del labels
def test():
  model.eval()
  test_loss = 0
  correct = 0
  with torch.no_grad():
      for data, target in validation_dataloader:
          data, target = data.to(device), target.to(device)
          output = model(data)
          test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
          pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
          correct += pred.eq(target.view_as(pred)).sum().item()
  test_loss /= len(validation_dataloader.dataset)

  print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
      test_loss, correct, len(validation_dataloader.dataset),
      100. * correct / len(validation_dataloader.dataset)))
  return 100. * correct / len(validation_dataloader.dataset)
# Out:
# torch.Size([32, 1, 450, 450])

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'

class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    addition = 20

    self.cl1 = nn.Conv2d(1,32,3,1,padding=2)
    self.cl2 = nn.Conv2d(32,32,3,1,padding=1)
    self.cl3 = nn.Conv2d(32,64,3,1,padding=1)
    self.cl4 = nn.Conv2d(64,64,3,1,padding=1)
    self.cl5 = nn.Conv2d(64,128,3,1,padding=1)
    self.cl6 = nn.Conv2d(128,128,3,1,padding=1)
    self.cl7 = nn.Conv2d(128,256,3,1,padding=1)
    self.cl8 = nn.Conv2d(256,256,3,1,padding=1)
    self.fc1 = nn.Linear(256 * (28**2), 256)
    self.fc2 = nn.Linear(256, 256)
    self.fc3 = nn.Linear(256, 10)
  def forward(self, x): 
    x = F.relu(self.cl1(x))
    # print(x.shape)
    x = F.relu(self.cl2(x))
    # print(x.shape)
    x = F.max_pool2d(x, 2, 2)
    # print(x.shape)
    x = F.relu(self.cl3(x))
    # print(x.shape)
    x = F.relu(self.cl4(x))
    # print(x.shape)
    x = F.max_pool2d(x, 2, 2)
    # print(x.shape)
    x = F.relu(self.cl5(x))
    # print(x.shape)
    x = F.relu(self.cl6(x))
    # print(x.shape)
    x = F.max_pool2d(x, 2, 2)
    # print(x.shape)
    x = F.relu(self.cl7(x))
    # print(x.shape)
    x = F.relu(self.cl8(x))
    # print(x.shape)
    x = F.max_pool2d(x, 2, 2)
    # print(x.shape)
    x = x.view(-1, self.fc1.in_features)
    x = F.relu(self.fc1(x))
    x = F.dropout2d(x)
    x = F.relu(self.fc2(x))
    x = F.dropout2d(x)
    x = self.fc3(x)
    x = torch.sigmoid(x) # used dim=1 to work on the data not on the batch
    return x
model = Net().to(device)
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.RMSprop(model.parameters(), lr=0.0001)#.Adam(model.parameters(), lr=0.002, amsgrad=True)
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[500,1000,1500], gamma=0.5)

# %%
gc.collect()
# Out:
# 35

# %%
epochs = 20
itr = 1
p_itr = 10
total_loss = 0
loss_list = []
acc_list = []
for epoch in range(epochs):
    gc.collect()
    model.train()
    for samples, labels in dataloader:
        samples, labels = samples.to(device), labels.to(device)
        optimizer.zero_grad()
        output = model(samples)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        scheduler.step()
        
        if itr%p_itr == 0:
            pred = torch.argmax(output, dim=1)
            correct = pred.eq(labels)
            acc = torch.mean(correct.float())
            print('[Epoch {}/{}] Iteration {} -> Train Loss: {:.4f}, Accuracy: {:.3f}'.format(epoch+1, epochs, itr, total_loss/p_itr, acc))
            loss_list.append(total_loss/p_itr)
            acc_list.append(acc)
            total_loss = 0
            
        itr += 1
    acc = test()
    torch.save(model.state_dict(),"/content/drive/My Drive/datasets/dogscats/cnn3.pt")
    if (acc > 85):
      break
    for param_group in optimizer.param_groups:
      param_group['lr'] = param_group['lr'] * 0.95
print(itr)
# Out:
# [Epoch 1/20] Iteration 10 -> Train Loss: 1.7785, Accuracy: 0.469
# [Epoch 1/20] Iteration 20 -> Train Loss: 1.6091, Accuracy: 0.469
# [Epoch 1/20] Iteration 30 -> Train Loss: 1.6027, Accuracy: 0.625
# [Epoch 1/20] Iteration 40 -> Train Loss: 1.6030, Accuracy: 0.344
# [Epoch 1/20] Iteration 50 -> Train Loss: 1.6011, Accuracy: 0.469
# [Epoch 1/20] Iteration 60 -> Train Loss: 1.6030, Accuracy: 0.375
# [Epoch 1/20] Iteration 70 -> Train Loss: 1.6003, Accuracy: 0.719
# [Epoch 1/20] Iteration 80 -> Train Loss: 1.5996, Accuracy: 0.562
# [Epoch 1/20] Iteration 90 -> Train Loss: 1.5999, Accuracy: 0.531
# [Epoch 1/20] Iteration 100 -> Train Loss: 1.6001, Accuracy: 0.562
# [Epoch 1/20] Iteration 110 -> Train Loss: 1.6014, Accuracy: 0.469
# [Epoch 1/20] Iteration 120 -> Train Loss: 1.5989, Accuracy: 0.344
# [Epoch 1/20] Iteration 130 -> Train Loss: 1.6007, Accuracy: 0.531
# [Epoch 1/20] Iteration 140 -> Train Loss: 1.5998, Accuracy: 0.438
# [Epoch 1/20] Iteration 150 -> Train Loss: 1.5987, Accuracy: 0.500
# [Epoch 1/20] Iteration 160 -> Train Loss: 1.5987, Accuracy: 0.500
# [Epoch 1/20] Iteration 170 -> Train Loss: 1.5984, Accuracy: 0.531
# [Epoch 1/20] Iteration 180 -> Train Loss: 1.5992, Accuracy: 0.500
# [Epoch 1/20] Iteration 190 -> Train Loss: 1.5986, Accuracy: 0.438
# [Epoch 1/20] Iteration 200 -> Train Loss: 1.5985, Accuracy: 0.656
# [Epoch 1/20] Iteration 210 -> Train Loss: 1.5982, Accuracy: 0.406
# [Epoch 1/20] Iteration 220 -> Train Loss: 1.5980, Accuracy: 0.531
# [Epoch 1/20] Iteration 230 -> Train Loss: 1.5993, Accuracy: 0.469
# [Epoch 1/20] Iteration 240 -> Train Loss: 1.5987, Accuracy: 0.500
# [Epoch 1/20] Iteration 250 -> Train Loss: 1.6001, Accuracy: 0.562
# [Epoch 1/20] Iteration 260 -> Train Loss: 1.5980, Accuracy: 0.375
# [Epoch 1/20] Iteration 270 -> Train Loss: 1.6019, Accuracy: 0.594
# [Epoch 1/20] Iteration 280 -> Train Loss: 1.5980, Accuracy: 0.500
# [Epoch 1/20] Iteration 290 -> Train Loss: 1.6025, Accuracy: 0.531
# [Epoch 1/20] Iteration 300 -> Train Loss: 1.6003, Accuracy: 0.375
# [Epoch 1/20] Iteration 310 -> Train Loss: 1.5983, Accuracy: 0.500
# [Epoch 1/20] Iteration 320 -> Train Loss: 1.6014, Accuracy: 0.625
# [Epoch 1/20] Iteration 330 -> Train Loss: 1.6040, Accuracy: 0.344
# [Epoch 1/20] Iteration 340 -> Train Loss: 1.5986, Accuracy: 0.656
# [Epoch 1/20] Iteration 350 -> Train Loss: 1.5984, Accuracy: 0.656
# [Epoch 1/20] Iteration 360 -> Train Loss: 1.5976, Accuracy: 0.406
# [Epoch 1/20] Iteration 370 -> Train Loss: 1.5976, Accuracy: 0.562
# [Epoch 1/20] Iteration 380 -> Train Loss: 1.5991, Accuracy: 0.688
# [Epoch 1/20] Iteration 390 -> Train Loss: 1.6000, Accuracy: 0.531
# [Epoch 1/20] Iteration 400 -> Train Loss: 1.6006, Accuracy: 0.562
# [Epoch 1/20] Iteration 410 -> Train Loss: 1.5967, Accuracy: 0.500
# [Epoch 1/20] Iteration 420 -> Train Loss: 1.6034, Accuracy: 0.469
# [Epoch 1/20] Iteration 430 -> Train Loss: 1.5989, Accuracy: 0.438
# [Epoch 1/20] Iteration 440 -> Train Loss: 1.5984, Accuracy: 0.562
# [Epoch 1/20] Iteration 450 -> Train Loss: 1.6004, Accuracy: 0.406
# [Epoch 1/20] Iteration 460 -> Train Loss: 1.5984, Accuracy: 0.500
# [Epoch 1/20] Iteration 470 -> Train Loss: 1.5991, Accuracy: 0.500
# [Epoch 1/20] Iteration 480 -> Train Loss: 1.6027, Accuracy: 0.594
# [Epoch 1/20] Iteration 490 -> Train Loss: 1.6007, Accuracy: 0.406
# [Epoch 1/20] Iteration 500 -> Train Loss: 1.5984, Accuracy: 0.656
# [Epoch 1/20] Iteration 510 -> Train Loss: 1.5979, Accuracy: 0.469
# [Epoch 1/20] Iteration 520 -> Train Loss: 1.5983, Accuracy: 0.438
# [Epoch 1/20] Iteration 530 -> Train Loss: 1.5980, Accuracy: 0.406
# [Epoch 1/20] Iteration 540 -> Train Loss: 1.5980, Accuracy: 0.625
# [Epoch 1/20] Iteration 550 -> Train Loss: 1.5987, Accuracy: 0.438
# [Epoch 1/20] Iteration 560 -> Train Loss: 1.5980, Accuracy: 0.500
#
# Test set: Average loss: -1.0000, Accuracy: 500/1000 (50%)
#
# [Epoch 2/20] Iteration 570 -> Train Loss: 1.5982, Accuracy: 0.625
# [Epoch 2/20] Iteration 580 -> Train Loss: 1.5980, Accuracy: 0.438
# [Epoch 2/20] Iteration 590 -> Train Loss: 1.5984, Accuracy: 0.469
# [Epoch 2/20] Iteration 600 -> Train Loss: 1.5991, Accuracy: 0.469
# [Epoch 2/20] Iteration 610 -> Train Loss: 1.5987, Accuracy: 0.531
# [Epoch 2/20] Iteration 620 -> Train Loss: 1.5980, Accuracy: 0.562
# [Epoch 2/20] Iteration 630 -> Train Loss: 1.5984, Accuracy: 0.500
# [Epoch 2/20] Iteration 640 -> Train Loss: 1.5980, Accuracy: 0.406
# [Epoch 2/20] Iteration 650 -> Train Loss: 1.5984, Accuracy: 0.375
# [Epoch 2/20] Iteration 660 -> Train Loss: 1.5980, Accuracy: 0.438
# [Epoch 2/20] Iteration 670 -> Train Loss: 1.5984, Accuracy: 0.531
# [Epoch 2/20] Iteration 680 -> Train Loss: 1.6009, Accuracy: 0.531
# [Epoch 2/20] Iteration 690 -> Train Loss: 1.5980, Accuracy: 0.438
# [Epoch 2/20] Iteration 700 -> Train Loss: 1.5984, Accuracy: 0.562
# [Epoch 2/20] Iteration 710 -> Train Loss: 1.5980, Accuracy: 0.531
# [Epoch 2/20] Iteration 720 -> Train Loss: 1.5980, Accuracy: 0.594
# [Epoch 2/20] Iteration 730 -> Train Loss: 1.5980, Accuracy: 0.562
# [Epoch 2/20] Iteration 740 -> Train Loss: 1.5980, Accuracy: 0.438
# [Epoch 2/20] Iteration 750 -> Train Loss: 1.5976, Accuracy: 0.594
# [Epoch 2/20] Iteration 760 -> Train Loss: 1.5979, Accuracy: 0.469
# [Epoch 2/20] Iteration 770 -> Train Loss: 1.5980, Accuracy: 0.500
# [Epoch 2/20] Iteration 780 -> Train Loss: 1.5984, Accuracy: 0.469
# [Epoch 2/20] Iteration 790 -> Train Loss: 1.5980, Accuracy: 0.469
# [Epoch 2/20] Iteration 800 -> Train Loss: 1.6006, Accuracy: 0.562
# [Epoch 2/20] Iteration 810 -> Train Loss: 1.5980, Accuracy: 0.531
# [Epoch 2/20] Iteration 820 -> Train Loss: 1.5980, Accuracy: 0.594
# [Epoch 2/20] Iteration 830 -> Train Loss: 1.5980, Accuracy: 0.531
# [Epoch 2/20] Iteration 840 -> Train Loss: 1.5983, Accuracy: 0.500
# [Epoch 2/20] Iteration 850 -> Train Loss: 1.5984, Accuracy: 0.406
# [Epoch 2/20] Iteration 860 -> Train Loss: 1.5984, Accuracy: 0.562
# [Epoch 2/20] Iteration 870 -> Train Loss: 1.5980, Accuracy: 0.344
# [Epoch 2/20] Iteration 880 -> Train Loss: 1.5980, Accuracy: 0.469
# [Epoch 2/20] Iteration 890 -> Train Loss: 1.5976, Accuracy: 0.500
# [Epoch 2/20] Iteration 900 -> Train Loss: 1.5980, Accuracy: 0.500
# [Epoch 2/20] Iteration 910 -> Train Loss: 1.5980, Accuracy: 0.406
# [Epoch 2/20] Iteration 920 -> Train Loss: 1.5986, Accuracy: 0.469

# %%
criterion = nn.CrossEntropyLoss()
