# %% [markdown]
# <a href="https://colab.research.google.com/github/AmirOfir/Cats_and_dogs/blob/master/Identify_dog_or_cat_Tryout_2_more_channels.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tryout 2

# %%
import sys
import numpy as np
import torch
import torchvision
import torch.nn as nn

# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from torch.autograd import Function
from torchvision import transforms, datasets
import math

import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, ConcatDataset
import copy
import tqdm
from PIL import Image

# Load the data (extract)
import os
import zipfile
from pathlib import Path
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
if not (os.path.exists('tmp/train')):
  local_zip = '/content/drive/My Drive/datasets/dogscats/train.zip'
  zip_ref = zipfile.ZipFile(local_zip, 'r')
  zip_ref.extractall('/tmp')
  zip_ref.close()
  local_zip = '/content/drive/My Drive/datasets/dogscats/test.zip'
  zip_ref = zipfile.ZipFile(local_zip, 'r')
  zip_ref.extractall('/tmp')
  zip_ref.close()

base_dir = '/tmp'
train_dir = os.path.join(base_dir, 'train')
validation_dir = os.path.join(base_dir, 'test1')

train_fnames = os.listdir(train_dir)
validation_fnames = os.listdir(validation_dir)

train_cat_fnames = [os.path.join(train_dir, x) for x in train_fnames if x.startswith('cat')][:-500]
train_dog_fnames = [os.path.join(train_dir, x) for x in train_fnames if x.startswith('dog')][:-500]
validation_cat_fnames = [os.path.join(train_dir, x) for x in train_fnames if x.startswith('cat')][-500:]
validation_dog_fnames = [os.path.join(train_dir, x) for x in train_fnames if x.startswith('dog')][-500:]

print('total training cat images:', len(train_cat_fnames))
print('total training dog images:', len(train_dog_fnames))
print('total validation cat images:', len(validation_cat_fnames))
print('total validation dog images:', len(validation_dog_fnames))
# Out:
# total training cat images: 12000
# total training dog images: 12000
# total validation cat images: 500
# total validation dog images: 500

# %%
class CatDogDataset(Dataset):
    def __init__(self, file_list, label=-1, mode='train', transform = None):
        self.file_list = file_list
        self.label = label
        self.mode = mode
        self.transform = transform
        
    def __len__(self):
        return len(self.file_list)
    
    def __getitem__(self, idx):
        img = Image.open(self.file_list[idx])
        if self.transform:
            img = self.transform(img)
            
        if self.mode == 'train':
            img = img.numpy()
            return img.astype('float32'), self.label
        else:
            img = img.numpy()
            return img.astype('float32'), self.label #file_list[idx]
        
data_transform = transforms.Compose([
    transforms.Resize((45,45)),
    transforms.Resize((450,450)),
    transforms.Grayscale(),
    transforms.ToTensor()
])

train_cats_ds = CatDogDataset(train_cat_fnames, 0, transform = data_transform)
train_dogs_ds = CatDogDataset(train_dog_fnames, 1, transform = data_transform)

train_catdogs_ds = ConcatDataset([train_cats_ds, train_dogs_ds])
dataloader = DataLoader(train_catdogs_ds, batch_size = 32, shuffle=True, num_workers=4)

validation_cats = CatDogDataset(validation_cat_fnames, 0, transform = data_transform)
validation_dogs = CatDogDataset(validation_dog_fnames, 1, transform = data_transform)

validation_catdogs = ConcatDataset([validation_cats, validation_dogs])
validation_size = len(validation_cat_fnames) + len(validation_dog_fnames)
validation_dataloader = DataLoader(validation_catdogs, batch_size = int(validation_size / 100), shuffle=False, num_workers=4)

# %%
samples, labels = iter(dataloader).next()
print(samples.shape)
plt.figure(figsize=(16,24))
grid_imgs = torchvision.utils.make_grid(samples[:24])
np_grid_imgs = grid_imgs.numpy()
print(np_grid_imgs.shape)
# in tensor, image is (batch, width, height), so you have to transpose it to (width, height, batch) in numpy to show it.
plt.imshow(np.transpose(np_grid_imgs, (1,2,0)))
# Out:
# torch.Size([32, 1, 450, 450])
# (3, 1358, 3618)

# %%
device = 'cuda'

class Net(nn.Module):
  def __init__(self):
    super(Net, self).__init__()
    addition = 20

    self.cl1 = nn.Conv2d(1,addition,4,1,padding=1)
    self.cl2 = nn.Conv2d(addition,addition*2, 4,1,padding=1)
    addition *=2
    self.cl3 = nn.Conv2d(addition,addition*2, 4,1,padding=1)
    addition *=2
    self.cl4 = nn.Conv2d(addition,addition*2, 4,1,padding=1)
    addition *=2
    self.cl5 = nn.Conv2d(addition,addition*2, 4,1,padding=1) #torch.Size([32, 140, 13, 13]) end
    addition *=2
    self.fc1 = nn.Linear( addition * (13**2), 500)
    self.fc2 = nn.Linear(500, 10)
  def forward(self, x): 
    x = F.relu(self.cl1(x))
    x = F.max_pool2d(x, 2, 2)
    x = F.relu(self.cl2(x))
    x = F.max_pool2d(x, 2, 2)
    x = F.relu(self.cl3(x))
    x = F.max_pool2d(x, 2, 2)
    x = F.relu(self.cl4(x))
    x = F.max_pool2d(x, 2, 2)
    x = F.relu(self.cl5(x))
    x = F.max_pool2d(x, 2, 2)
    x = x.view(-1, self.fc1.in_features)
    x = F.relu(self.fc1(x)) # new size is batch x 500
    x = self.fc2(x) # new size is batch x 10
    x = F.log_softmax(x, dim=1) # used dim=1 to work on the data not on the batch
    return x
model = Net().to(device)
model = model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.002, amsgrad=True)
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[500,1000,1500], gamma=0.5)

# %%
def test():
  model.eval()
  test_loss = 0
  correct = 0
  with torch.no_grad():
      for data, target in validation_dataloader:
          data, target = data.to(device), target.to(device)
          output = model(data)
          test_loss += F.nll_loss(output, target, reduction='sum').item() # sum up batch loss
          pred = output.argmax(dim=1, keepdim=True) # get the index of the max log-probability
          correct += pred.eq(target.view_as(pred)).sum().item()
  test_loss /= len(validation_dataloader.dataset)

  print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
      test_loss, correct, len(validation_dataloader.dataset),
      100. * correct / len(validation_dataloader.dataset)))
  return 100. * correct / len(validation_dataloader.dataset)

# %%
epochs = 15
itr = 1
p_itr = 10
total_loss = 0
loss_list = []
acc_list = []
for epoch in range(epochs):
    model.train()
    for samples, labels in dataloader:
        samples, labels = samples.to(device), labels.to(device)
        optimizer.zero_grad()
        output = model(samples)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        scheduler.step()
        
        if itr%p_itr == 0:
            pred = torch.argmax(output, dim=1)
            correct = pred.eq(labels)
            acc = torch.mean(correct.float())
            print('[Epoch {}/{}] Iteration {} -> Train Loss: {:.4f}, Accuracy: {:.3f}'.format(epoch+1, epochs, itr, total_loss/p_itr, acc))
            loss_list.append(total_loss/p_itr)
            acc_list.append(acc)
            total_loss = 0
            
        itr += 1
    acc = test()
    if (acc > 85):
      break
    for param_group in optimizer.param_groups:
      param_group['lr'] = param_group['lr'] * 0.95
print(itr)
plt.plot(loss_list, label='loss')
plt.plot(acc_list, label='accuracy')
plt.legend()
plt.title('training loss and accuracy')
plt.show()
# Out:
# [Epoch 1/15] Iteration 10 -> Train Loss: 0.0945, Accuracy: 0.938
# [Epoch 1/15] Iteration 20 -> Train Loss: 0.0819, Accuracy: 0.969
# [Epoch 1/15] Iteration 30 -> Train Loss: 0.0746, Accuracy: 1.000
# [Epoch 1/15] Iteration 40 -> Train Loss: 0.0831, Accuracy: 0.969
# [Epoch 1/15] Iteration 50 -> Train Loss: 0.0630, Accuracy: 1.000
# [Epoch 1/15] Iteration 60 -> Train Loss: 0.0904, Accuracy: 1.000
# [Epoch 1/15] Iteration 70 -> Train Loss: 0.0726, Accuracy: 1.000
# [Epoch 1/15] Iteration 80 -> Train Loss: 0.0880, Accuracy: 1.000
# [Epoch 1/15] Iteration 90 -> Train Loss: 0.0798, Accuracy: 0.938
# [Epoch 1/15] Iteration 100 -> Train Loss: 0.0873, Accuracy: 0.969
# [Epoch 1/15] Iteration 110 -> Train Loss: 0.0905, Accuracy: 0.969
# [Epoch 1/15] Iteration 120 -> Train Loss: 0.1018, Accuracy: 0.938
# [Epoch 1/15] Iteration 130 -> Train Loss: 0.1006, Accuracy: 0.938
# [Epoch 1/15] Iteration 140 -> Train Loss: 0.0724, Accuracy: 1.000
# [Epoch 1/15] Iteration 150 -> Train Loss: 0.0894, Accuracy: 1.000
# [Epoch 1/15] Iteration 160 -> Train Loss: 0.0692, Accuracy: 0.969
# [Epoch 1/15] Iteration 170 -> Train Loss: 0.0615, Accuracy: 0.969
# [Epoch 1/15] Iteration 180 -> Train Loss: 0.0864, Accuracy: 1.000
# [Epoch 1/15] Iteration 190 -> Train Loss: 0.0688, Accuracy: 1.000
# [Epoch 1/15] Iteration 200 -> Train Loss: 0.0716, Accuracy: 1.000
# [Epoch 1/15] Iteration 210 -> Train Loss: 0.0658, Accuracy: 0.969
# [Epoch 1/15] Iteration 220 -> Train Loss: 0.0638, Accuracy: 1.000
# [Epoch 1/15] Iteration 230 -> Train Loss: 0.0897, Accuracy: 0.969
# [Epoch 1/15] Iteration 240 -> Train Loss: 0.0767, Accuracy: 0.969
# [Epoch 1/15] Iteration 250 -> Train Loss: 0.0606, Accuracy: 1.000
# [Epoch 1/15] Iteration 260 -> Train Loss: 0.0946, Accuracy: 1.000
# [Epoch 1/15] Iteration 270 -> Train Loss: 0.0759, Accuracy: 0.969
# [Epoch 1/15] Iteration 280 -> Train Loss: 0.0893, Accuracy: 0.969
# [Epoch 1/15] Iteration 290 -> Train Loss: 0.0885, Accuracy: 0.969
# [Epoch 1/15] Iteration 300 -> Train Loss: 0.0742, Accuracy: 1.000
# [Epoch 1/15] Iteration 310 -> Train Loss: 0.0657, Accuracy: 1.000
# [Epoch 1/15] Iteration 320 -> Train Loss: 0.0712, Accuracy: 1.000
# [Epoch 1/15] Iteration 330 -> Train Loss: 0.0693, Accuracy: 1.000
# [Epoch 1/15] Iteration 340 -> Train Loss: 0.0995, Accuracy: 0.938
# [Epoch 1/15] Iteration 350 -> Train Loss: 0.0865, Accuracy: 0.969
# [Epoch 1/15] Iteration 360 -> Train Loss: 0.0671, Accuracy: 1.000
# [Epoch 1/15] Iteration 370 -> Train Loss: 0.0989, Accuracy: 1.000
# [Epoch 1/15] Iteration 380 -> Train Loss: 0.0805, Accuracy: 0.938
# [Epoch 1/15] Iteration 390 -> Train Loss: 0.0991, Accuracy: 0.938
# [Epoch 1/15] Iteration 400 -> Train Loss: 0.1255, Accuracy: 0.969
# [Epoch 1/15] Iteration 410 -> Train Loss: 0.1174, Accuracy: 0.969
# [Epoch 1/15] Iteration 420 -> Train Loss: 0.0976, Accuracy: 1.000
# [Epoch 1/15] Iteration 430 -> Train Loss: 0.0875, Accuracy: 0.969
# [Epoch 1/15] Iteration 440 -> Train Loss: 0.0696, Accuracy: 0.969
# [Epoch 1/15] Iteration 450 -> Train Loss: 0.0904, Accuracy: 0.969
# [Epoch 1/15] Iteration 460 -> Train Loss: 0.1210, Accuracy: 0.938
# [Epoch 1/15] Iteration 470 -> Train Loss: 0.0971, Accuracy: 0.969
# [Epoch 1/15] Iteration 480 -> Train Loss: 0.0697, Accuracy: 0.969
# [Epoch 1/15] Iteration 490 -> Train Loss: 0.1079, Accuracy: 0.969
# [Epoch 1/15] Iteration 500 -> Train Loss: 0.1161, Accuracy: 0.969
# [Epoch 1/15] Iteration 510 -> Train Loss: 0.0891, Accuracy: 1.000
# [Epoch 1/15] Iteration 520 -> Train Loss: 0.1094, Accuracy: 1.000
# [Epoch 1/15] Iteration 530 -> Train Loss: 0.0931, Accuracy: 0.938
# [Epoch 1/15] Iteration 540 -> Train Loss: 0.0845, Accuracy: 0.969
# [Epoch 1/15] Iteration 550 -> Train Loss: 0.0783, Accuracy: 0.938
# [Epoch 1/15] Iteration 560 -> Train Loss: 0.0866, Accuracy: 1.000
# [Epoch 1/15] Iteration 570 -> Train Loss: 0.0687, Accuracy: 0.938
# [Epoch 1/15] Iteration 580 -> Train Loss: 0.1056, Accuracy: 0.875
# [Epoch 1/15] Iteration 590 -> Train Loss: 0.0680, Accuracy: 1.000
# [Epoch 1/15] Iteration 600 -> Train Loss: 0.0766, Accuracy: 0.969
# [Epoch 1/15] Iteration 610 -> Train Loss: 0.1081, Accuracy: 1.000
# [Epoch 1/15] Iteration 620 -> Train Loss: 0.0937, Accuracy: 0.969
# [Epoch 1/15] Iteration 630 -> Train Loss: 0.0857, Accuracy: 0.938
# [Epoch 1/15] Iteration 640 -> Train Loss: 0.1034, Accuracy: 0.906
# [Epoch 1/15] Iteration 650 -> Train Loss: 0.0766, Accuracy: 1.000
# [Epoch 1/15] Iteration 660 -> Train Loss: 0.0797, Accuracy: 1.000
# [Epoch 1/15] Iteration 670 -> Train Loss: 0.0911, Accuracy: 1.000
# [Epoch 1/15] Iteration 680 -> Train Loss: 0.1331, Accuracy: 1.000
# [Epoch 1/15] Iteration 690 -> Train Loss: 0.0784, Accuracy: 0.938
# [Epoch 1/15] Iteration 700 -> Train Loss: 0.1191, Accuracy: 0.969
# [Epoch 1/15] Iteration 710 -> Train Loss: 0.0809, Accuracy: 0.906
# [Epoch 1/15] Iteration 720 -> Train Loss: 0.0739, Accuracy: 1.000
# [Epoch 1/15] Iteration 730 -> Train Loss: 0.1451, Accuracy: 0.938
# [Epoch 1/15] Iteration 740 -> Train Loss: 0.1553, Accuracy: 0.938
# [Epoch 1/15] Iteration 750 -> Train Loss: 0.1079, Accuracy: 1.000
#
# Test set: Average loss: 1.4104, Accuracy: 716/1000 (72%)
#
# [Epoch 2/15] Iteration 760 -> Train Loss: 0.0953, Accuracy: 0.906
# [Epoch 2/15] Iteration 770 -> Train Loss: 0.0424, Accuracy: 0.969
# [Epoch 2/15] Iteration 780 -> Train Loss: 0.0493, Accuracy: 1.000
# [Epoch 2/15] Iteration 790 -> Train Loss: 0.0575, Accuracy: 0.969
# [Epoch 2/15] Iteration 800 -> Train Loss: 0.0473, Accuracy: 1.000
# [Epoch 2/15] Iteration 810 -> Train Loss: 0.0570, Accuracy: 1.000
# [Epoch 2/15] Iteration 820 -> Train Loss: 0.0601, Accuracy: 0.969
# [Epoch 2/15] Iteration 830 -> Train Loss: 0.0533, Accuracy: 1.000
# [Epoch 2/15] Iteration 840 -> Train Loss: 0.0484, Accuracy: 1.000
# [Epoch 2/15] Iteration 850 -> Train Loss: 0.1123, Accuracy: 1.000
# [Epoch 2/15] Iteration 860 -> Train Loss: 0.0814, Accuracy: 0.969
# [Epoch 2/15] Iteration 870 -> Train Loss: 0.0537, Accuracy: 1.000
# [Epoch 2/15] Iteration 880 -> Train Loss: 0.0678, Accuracy: 0.938
# [Epoch 2/15] Iteration 890 -> Train Loss: 0.0501, Accuracy: 1.000
# [Epoch 2/15] Iteration 900 -> Train Loss: 0.0537, Accuracy: 1.000
# [Epoch 2/15] Iteration 910 -> Train Loss: 0.0695, Accuracy: 0.938
# [Epoch 2/15] Iteration 920 -> Train Loss: 0.0505, Accuracy: 0.969
# [Epoch 2/15] Iteration 930 -> Train Loss: 0.0470, Accuracy: 1.000
# [Epoch 2/15] Iteration 940 -> Train Loss: 0.0877, Accuracy: 1.000
# [Epoch 2/15] Iteration 950 -> Train Loss: 0.0639, Accuracy: 0.969
# [Epoch 2/15] Iteration 960 -> Train Loss: 0.0614, Accuracy: 0.938
# [Epoch 2/15] Iteration 970 -> Train Loss: 0.0496, Accuracy: 1.000
# [Epoch 2/15] Iteration 980 -> Train Loss: 0.0469, Accuracy: 1.000
# [Epoch 2/15] Iteration 990 -> Train Loss: 0.0491, Accuracy: 0.969
# [Epoch 2/15] Iteration 1000 -> Train Loss: 0.0602, Accuracy: 0.969
# [Epoch 2/15] Iteration 1010 -> Train Loss: 0.0656, Accuracy: 0.969
# [Epoch 2/15] Iteration 1020 -> Train Loss: 0.0374, Accuracy: 0.938
# [Epoch 2/15] Iteration 1030 -> Train Loss: 0.0685, Accuracy: 0.969
# [Epoch 2/15] Iteration 1040 -> Train Loss: 0.0934, Accuracy: 0.906
# [Epoch 2/15] Iteration 1050 -> Train Loss: 0.0822, Accuracy: 0.969
# [Epoch 2/15] Iteration 1060 -> Train Loss: 0.0728, Accuracy: 0.969
# [Epoch 2/15] Iteration 1070 -> Train Loss: 0.0717, Accuracy: 0.969
# [Epoch 2/15] Iteration 1080 -> Train Loss: 0.0695, Accuracy: 0.969
# [Epoch 2/15] Iteration 1090 -> Train Loss: 0.0606, Accuracy: 1.000
# [Epoch 2/15] Iteration 1100 -> Train Loss: 0.0542, Accuracy: 1.000
# [Epoch 2/15] Iteration 1110 -> Train Loss: 0.0532, Accuracy: 1.000
# [Epoch 2/15] Iteration 1120 -> Train Loss: 0.0587, Accuracy: 0.969
# [Epoch 2/15] Iteration 1130 -> Train Loss: 0.0555, Accuracy: 1.000
# [Epoch 2/15] Iteration 1140 -> Train Loss: 0.0818, Accuracy: 1.000
# [Epoch 2/15] Iteration 1150 -> Train Loss: 0.0880, Accuracy: 0.969
# [Epoch 2/15] Iteration 1160 -> Train Loss: 0.0766, Accuracy: 0.969
# [Epoch 2/15] Iteration 1170 -> Train Loss: 0.0597, Accuracy: 1.000
# [Epoch 2/15] Iteration 1180 -> Train Loss: 0.0794, Accuracy: 0.969
# [Epoch 2/15] Iteration 1190 -> Train Loss: 0.0743, Accuracy: 1.000
# [Epoch 2/15] Iteration 1200 -> Train Loss: 0.1160, Accuracy: 0.969
# [Epoch 2/15] Iteration 1210 -> Train Loss: 0.1015, Accuracy: 1.000
# [Epoch 2/15] Iteration 1220 -> Train Loss: 0.0671, Accuracy: 0.906
# [Epoch 2/15] Iteration 1230 -> Train Loss: 0.1647, Accuracy: 1.000
# [Epoch 2/15] Iteration 1240 -> Train Loss: 0.0496, Accuracy: 1.000
# [Epoch 2/15] Iteration 1250 -> Train Loss: 0.1268, Accuracy: 0.875
# [Epoch 2/15] Iteration 1260 -> Train Loss: 0.0591, Accuracy: 1.000
# [Epoch 2/15] Iteration 1270 -> Train Loss: 0.0891, Accuracy: 1.000
# [Epoch 2/15] Iteration 1280 -> Train Loss: 0.0947, Accuracy: 1.000
# [Epoch 2/15] Iteration 1290 -> Train Loss: 0.0854, Accuracy: 1.000
# [Epoch 2/15] Iteration 1300 -> Train Loss: 0.0904, Accuracy: 0.969
# [Epoch 2/15] Iteration 1310 -> Train Loss: 0.0766, Accuracy: 1.000
# [Epoch 2/15] Iteration 1320 -> Train Loss: 0.0593, Accuracy: 0.969
# [Epoch 2/15] Iteration 1330 -> Train Loss: 0.0835, Accuracy: 0.969
# [Epoch 2/15] Iteration 1340 -> Train Loss: 0.0695, Accuracy: 0.969
# [Epoch 2/15] Iteration 1350 -> Train Loss: 0.0846, Accuracy: 0.969
# [Epoch 2/15] Iteration 1360 -> Train Loss: 0.0630, Accuracy: 0.938
# [Epoch 2/15] Iteration 1370 -> Train Loss: 0.0527, Accuracy: 0.969
# [Epoch 2/15] Iteration 1380 -> Train Loss: 0.0710, Accuracy: 0.938
# [Epoch 2/15] Iteration 1390 -> Train Loss: 0.0414, Accuracy: 1.000
# [Epoch 2/15] Iteration 1400 -> Train Loss: 0.0526, Accuracy: 1.000
# [Epoch 2/15] Iteration 1410 -> Train Loss: 0.0743, Accuracy: 0.875
# [Epoch 2/15] Iteration 1420 -> Train Loss: 0.0659, Accuracy: 1.000
# [Epoch 2/15] Iteration 1430 -> Train Loss: 0.0472, Accuracy: 1.000
# [Epoch 2/15] Iteration 1440 -> Train Loss: 0.0797, Accuracy: 1.000
# [Epoch 2/15] Iteration 1450 -> Train Loss: 0.0441, Accuracy: 0.969
# [Epoch 2/15] Iteration 1460 -> Train Loss: 0.0534, Accuracy: 1.000
# [Epoch 2/15] Iteration 1470 -> Train Loss: 0.0929, Accuracy: 1.000
# [Epoch 2/15] Iteration 1480 -> Train Loss: 0.1224, Accuracy: 0.969
# [Epoch 2/15] Iteration 1490 -> Train Loss: 0.0582, Accuracy: 1.000
# [Epoch 2/15] Iteration 1500 -> Train Loss: 0.0533, Accuracy: 0.969
#
# Test set: Average loss: 1.5632, Accuracy: 721/1000 (72%)
#
# [Epoch 3/15] Iteration 1510 -> Train Loss: 0.0353, Accuracy: 0.938
# [Epoch 3/15] Iteration 1520 -> Train Loss: 0.0429, Accuracy: 1.000
# [Epoch 3/15] Iteration 1530 -> Train Loss: 0.0357, Accuracy: 1.000
# [Epoch 3/15] Iteration 1540 -> Train Loss: 0.1867, Accuracy: 1.000
# [Epoch 3/15] Iteration 1550 -> Train Loss: 0.0628, Accuracy: 0.969
# [Epoch 3/15] Iteration 1560 -> Train Loss: 0.0790, Accuracy: 0.969
# [Epoch 3/15] Iteration 1570 -> Train Loss: 0.0396, Accuracy: 1.000
# [Epoch 3/15] Iteration 1580 -> Train Loss: 0.0444, Accuracy: 1.000
# [Epoch 3/15] Iteration 1590 -> Train Loss: 0.0396, Accuracy: 0.969
# [Epoch 3/15] Iteration 1600 -> Train Loss: 0.0489, Accuracy: 1.000
# [Epoch 3/15] Iteration 1610 -> Train Loss: 0.0512, Accuracy: 0.969
# [Epoch 3/15] Iteration 1620 -> Train Loss: 0.0422, Accuracy: 1.000
# [Epoch 3/15] Iteration 1630 -> Train Loss: 0.0297, Accuracy: 1.000
# [Epoch 3/15] Iteration 1640 -> Train Loss: 0.0368, Accuracy: 1.000
# [Epoch 3/15] Iteration 1650 -> Train Loss: 0.0332, Accuracy: 1.000
# [Epoch 3/15] Iteration 1660 -> Train Loss: 0.0414, Accuracy: 1.000
# [Epoch 3/15] Iteration 1670 -> Train Loss: 0.0646, Accuracy: 0.969
# [Epoch 3/15] Iteration 1680 -> Train Loss: 0.0255, Accuracy: 1.000
# [Epoch 3/15] Iteration 1690 -> Train Loss: 0.0383, Accuracy: 1.000
# [Epoch 3/15] Iteration 1700 -> Train Loss: 0.0331, Accuracy: 0.969
# [Epoch 3/15] Iteration 1710 -> Train Loss: 0.0503, Accuracy: 0.969
# [Epoch 3/15] Iteration 1720 -> Train Loss: 0.0273, Accuracy: 0.969
# [Epoch 3/15] Iteration 1730 -> Train Loss: 0.0483, Accuracy: 1.000
# [Epoch 3/15] Iteration 1740 -> Train Loss: 0.0227, Accuracy: 1.000
# [Epoch 3/15] Iteration 1750 -> Train Loss: 0.0336, Accuracy: 1.000
# [Epoch 3/15] Iteration 1760 -> Train Loss: 0.0448, Accuracy: 1.000
# [Epoch 3/15] Iteration 1770 -> Train Loss: 0.0302, Accuracy: 1.000
# [Epoch 3/15] Iteration 1780 -> Train Loss: 0.0282, Accuracy: 1.000
# [Epoch 3/15] Iteration 1790 -> Train Loss: 0.0562, Accuracy: 1.000
# [Epoch 3/15] Iteration 1800 -> Train Loss: 0.0623, Accuracy: 1.000
# [Epoch 3/15] Iteration 1810 -> Train Loss: 0.0420, Accuracy: 0.969
# [Epoch 3/15] Iteration 1820 -> Train Loss: 0.0632, Accuracy: 1.000
# [Epoch 3/15] Iteration 1830 -> Train Loss: 0.1314, Accuracy: 0.938
# [Epoch 3/15] Iteration 1840 -> Train Loss: 0.0596, Accuracy: 0.938
# [Epoch 3/15] Iteration 1850 -> Train Loss: 0.0357, Accuracy: 1.000
# [Epoch 3/15] Iteration 1860 -> Train Loss: 0.0526, Accuracy: 1.000
# [Epoch 3/15] Iteration 1870 -> Train Loss: 0.0709, Accuracy: 1.000
# [Epoch 3/15] Iteration 1880 -> Train Loss: 0.0358, Accuracy: 1.000
# [Epoch 3/15] Iteration 1890 -> Train Loss: 0.1137, Accuracy: 1.000
# [Epoch 3/15] Iteration 1900 -> Train Loss: 0.0554, Accuracy: 0.938
# [Epoch 3/15] Iteration 1910 -> Train Loss: 0.0840, Accuracy: 1.000
# [Epoch 3/15] Iteration 1920 -> Train Loss: 0.0778, Accuracy: 1.000
# [Epoch 3/15] Iteration 1930 -> Train Loss: 0.0570, Accuracy: 0.969
# [Epoch 3/15] Iteration 1940 -> Train Loss: 0.0600, Accuracy: 0.969
# [Epoch 3/15] Iteration 1950 -> Train Loss: 0.0654, Accuracy: 1.000
# [Epoch 3/15] Iteration 1960 -> Train Loss: 0.0575, Accuracy: 0.938
# [Epoch 3/15] Iteration 1970 -> Train Loss: 0.0313, Accuracy: 1.000
# [Epoch 3/15] Iteration 1980 -> Train Loss: 0.0443, Accuracy: 0.969
# [Epoch 3/15] Iteration 1990 -> Train Loss: 0.0566, Accuracy: 1.000
# [Epoch 3/15] Iteration 2000 -> Train Loss: 0.1101, Accuracy: 1.000
# [Epoch 3/15] Iteration 2010 -> Train Loss: 0.0583, Accuracy: 1.000
# [Epoch 3/15] Iteration 2020 -> Train Loss: 0.0560, Accuracy: 1.000
# [Epoch 3/15] Iteration 2030 -> Train Loss: 0.0675, Accuracy: 1.000
# [Epoch 3/15] Iteration 2040 -> Train Loss: 0.0505, Accuracy: 0.969
# [Epoch 3/15] Iteration 2050 -> Train Loss: 0.0463, Accuracy: 1.000
# [Epoch 3/15] Iteration 2060 -> Train Loss: 0.0544, Accuracy: 1.000
# [Epoch 3/15] Iteration 2070 -> Train Loss: 0.0568, Accuracy: 0.969
# [Epoch 3/15] Iteration 2080 -> Train Loss: 0.0668, Accuracy: 1.000
# [Epoch 3/15] Iteration 2090 -> Train Loss: 0.0356, Accuracy: 1.000
# [Epoch 3/15] Iteration 2100 -> Train Loss: 0.0469, Accuracy: 1.000
# [Epoch 3/15] Iteration 2110 -> Train Loss: 0.0466, Accuracy: 1.000
# [Epoch 3/15] Iteration 2120 -> Train Loss: 0.0297, Accuracy: 1.000
# [Epoch 3/15] Iteration 2130 -> Train Loss: 0.0602, Accuracy: 0.969
# [Epoch 3/15] Iteration 2140 -> Train Loss: 0.0434, Accuracy: 0.938
# [Epoch 3/15] Iteration 2150 -> Train Loss: 0.0416, Accuracy: 1.000
# [Epoch 3/15] Iteration 2160 -> Train Loss: 0.0640, Accuracy: 1.000
# [Epoch 3/15] Iteration 2170 -> Train Loss: 0.0692, Accuracy: 0.938
# [Epoch 3/15] Iteration 2180 -> Train Loss: 0.0427, Accuracy: 1.000
# [Epoch 3/15] Iteration 2190 -> Train Loss: 0.0559, Accuracy: 1.000
# [Epoch 3/15] Iteration 2200 -> Train Loss: 0.0408, Accuracy: 1.000
# [Epoch 3/15] Iteration 2210 -> Train Loss: 0.0686, Accuracy: 1.000
# [Epoch 3/15] Iteration 2220 -> Train Loss: 0.0368, Accuracy: 1.000
# [Epoch 3/15] Iteration 2230 -> Train Loss: 0.0340, Accuracy: 1.000
# [Epoch 3/15] Iteration 2240 -> Train Loss: 0.0551, Accuracy: 0.938
# [Epoch 3/15] Iteration 2250 -> Train Loss: 0.0555, Accuracy: 0.969
#
# Test set: Average loss: 1.6366, Accuracy: 731/1000 (73%)
#
# [Epoch 4/15] Iteration 2260 -> Train Loss: 0.0300, Accuracy: 0.969
# [Epoch 4/15] Iteration 2270 -> Train Loss: 0.0278, Accuracy: 0.969
# [Epoch 4/15] Iteration 2280 -> Train Loss: 0.0258, Accuracy: 1.000
# [Epoch 4/15] Iteration 2290 -> Train Loss: 0.0398, Accuracy: 1.000
# [Epoch 4/15] Iteration 2300 -> Train Loss: 0.0953, Accuracy: 1.000
# [Epoch 4/15] Iteration 2310 -> Train Loss: 0.0213, Accuracy: 1.000
# [Epoch 4/15] Iteration 2320 -> Train Loss: 0.0410, Accuracy: 0.969
# [Epoch 4/15] Iteration 2330 -> Train Loss: 0.0277, Accuracy: 1.000
# [Epoch 4/15] Iteration 2340 -> Train Loss: 0.1024, Accuracy: 1.000
# [Epoch 4/15] Iteration 2350 -> Train Loss: 0.0380, Accuracy: 1.000
# [Epoch 4/15] Iteration 2360 -> Train Loss: 0.0333, Accuracy: 1.000
# [Epoch 4/15] Iteration 2370 -> Train Loss: 0.0599, Accuracy: 1.000
# [Epoch 4/15] Iteration 2380 -> Train Loss: 0.0554, Accuracy: 1.000
# [Epoch 4/15] Iteration 2390 -> Train Loss: 0.0503, Accuracy: 1.000
# [Epoch 4/15] Iteration 2400 -> Train Loss: 0.0461, Accuracy: 1.000
# [Epoch 4/15] Iteration 2410 -> Train Loss: 0.0276, Accuracy: 1.000
# [Epoch 4/15] Iteration 2420 -> Train Loss: 0.0236, Accuracy: 1.000
# [Epoch 4/15] Iteration 2430 -> Train Loss: 0.0462, Accuracy: 0.938
# [Epoch 4/15] Iteration 2440 -> Train Loss: 0.0480, Accuracy: 0.969
# [Epoch 4/15] Iteration 2450 -> Train Loss: 0.0532, Accuracy: 1.000
# [Epoch 4/15] Iteration 2460 -> Train Loss: 0.0224, Accuracy: 1.000
# [Epoch 4/15] Iteration 2470 -> Train Loss: 0.0339, Accuracy: 0.969
# [Epoch 4/15] Iteration 2480 -> Train Loss: 0.0314, Accuracy: 0.969
# [Epoch 4/15] Iteration 2490 -> Train Loss: 0.0187, Accuracy: 1.000
# [Epoch 4/15] Iteration 2500 -> Train Loss: 0.0252, Accuracy: 1.000
# [Epoch 4/15] Iteration 2510 -> Train Loss: 0.0403, Accuracy: 0.969
# [Epoch 4/15] Iteration 2520 -> Train Loss: 0.0243, Accuracy: 1.000
# [Epoch 4/15] Iteration 2530 -> Train Loss: 0.0128, Accuracy: 1.000
# [Epoch 4/15] Iteration 2540 -> Train Loss: 0.0485, Accuracy: 0.969
# [Epoch 4/15] Iteration 2550 -> Train Loss: 0.0212, Accuracy: 1.000
# [Epoch 4/15] Iteration 2560 -> Train Loss: 0.0342, Accuracy: 1.000
# [Epoch 4/15] Iteration 2570 -> Train Loss: 0.0355, Accuracy: 0.969
# [Epoch 4/15] Iteration 2580 -> Train Loss: 0.0552, Accuracy: 1.000
# [Epoch 4/15] Iteration 2590 -> Train Loss: 0.0357, Accuracy: 1.000
# [Epoch 4/15] Iteration 2600 -> Train Loss: 0.0396, Accuracy: 1.000
# [Epoch 4/15] Iteration 2610 -> Train Loss: 0.0143, Accuracy: 1.000
# [Epoch 4/15] Iteration 2620 -> Train Loss: 0.0390, Accuracy: 1.000
# [Epoch 4/15] Iteration 2630 -> Train Loss: 0.0232, Accuracy: 0.969
# [Epoch 4/15] Iteration 2640 -> Train Loss: 0.0125, Accuracy: 1.000
# [Epoch 4/15] Iteration 2650 -> Train Loss: 0.0365, Accuracy: 1.000
# [Epoch 4/15] Iteration 2660 -> Train Loss: 0.0250, Accuracy: 1.000
# [Epoch 4/15] Iteration 2670 -> Train Loss: 0.0246, Accuracy: 1.000
# [Epoch 4/15] Iteration 2680 -> Train Loss: 0.0168, Accuracy: 1.000
# [Epoch 4/15] Iteration 2690 -> Train Loss: 0.0142, Accuracy: 1.000
# [Epoch 4/15] Iteration 2700 -> Train Loss: 0.0158, Accuracy: 1.000
# [Epoch 4/15] Iteration 2710 -> Train Loss: 0.0225, Accuracy: 1.000
# [Epoch 4/15] Iteration 2720 -> Train Loss: 0.0173, Accuracy: 1.000
# [Epoch 4/15] Iteration 2730 -> Train Loss: 0.0270, Accuracy: 1.000
# [Epoch 4/15] Iteration 2740 -> Train Loss: 0.0260, Accuracy: 1.000
# [Epoch 4/15] Iteration 2750 -> Train Loss: 0.0191, Accuracy: 1.000
# [Epoch 4/15] Iteration 2760 -> Train Loss: 0.0226, Accuracy: 0.969
# [Epoch 4/15] Iteration 2770 -> Train Loss: 0.0114, Accuracy: 1.000
# [Epoch 4/15] Iteration 2780 -> Train Loss: 0.0534, Accuracy: 1.000
# [Epoch 4/15] Iteration 2790 -> Train Loss: 0.0362, Accuracy: 0.969
# [Epoch 4/15] Iteration 2800 -> Train Loss: 0.0621, Accuracy: 1.000
# [Epoch 4/15] Iteration 2810 -> Train Loss: 0.0781, Accuracy: 1.000
# [Epoch 4/15] Iteration 2820 -> Train Loss: 0.0358, Accuracy: 1.000
# [Epoch 4/15] Iteration 2830 -> Train Loss: 0.0441, Accuracy: 0.969
# [Epoch 4/15] Iteration 2840 -> Train Loss: 0.0512, Accuracy: 1.000
# [Epoch 4/15] Iteration 2850 -> Train Loss: 0.0444, Accuracy: 1.000
# [Epoch 4/15] Iteration 2860 -> Train Loss: 0.0722, Accuracy: 1.000
# [Epoch 4/15] Iteration 2870 -> Train Loss: 0.0958, Accuracy: 0.969
# [Epoch 4/15] Iteration 2880 -> Train Loss: 0.0285, Accuracy: 1.000
# [Epoch 4/15] Iteration 2890 -> Train Loss: 0.0805, Accuracy: 1.000
# [Epoch 4/15] Iteration 2900 -> Train Loss: 0.0525, Accuracy: 0.969
# [Epoch 4/15] Iteration 2910 -> Train Loss: 0.0523, Accuracy: 1.000
# [Epoch 4/15] Iteration 2920 -> Train Loss: 0.0912, Accuracy: 0.969
# [Epoch 4/15] Iteration 2930 -> Train Loss: 0.0752, Accuracy: 0.938
# [Epoch 4/15] Iteration 2940 -> Train Loss: 0.0763, Accuracy: 0.969
# [Epoch 4/15] Iteration 2950 -> Train Loss: 0.0570, Accuracy: 1.000
# [Epoch 4/15] Iteration 2960 -> Train Loss: 0.1083, Accuracy: 0.906
# [Epoch 4/15] Iteration 2970 -> Train Loss: 0.0355, Accuracy: 1.000
# [Epoch 4/15] Iteration 2980 -> Train Loss: 0.0864, Accuracy: 1.000
# [Epoch 4/15] Iteration 2990 -> Train Loss: 0.0620, Accuracy: 0.969
# [Epoch 4/15] Iteration 3000 -> Train Loss: 0.1021, Accuracy: 1.000
#
# Test set: Average loss: 1.8392, Accuracy: 712/1000 (71%)
#
# [Epoch 5/15] Iteration 3010 -> Train Loss: 0.0392, Accuracy: 1.000
# [Epoch 5/15] Iteration 3020 -> Train Loss: 0.0692, Accuracy: 0.938
# [Epoch 5/15] Iteration 3030 -> Train Loss: 0.0262, Accuracy: 0.969
# [Epoch 5/15] Iteration 3040 -> Train Loss: 0.0425, Accuracy: 0.969
# [Epoch 5/15] Iteration 3050 -> Train Loss: 0.0211, Accuracy: 1.000
# [Epoch 5/15] Iteration 3060 -> Train Loss: 0.0773, Accuracy: 0.969
# [Epoch 5/15] Iteration 3070 -> Train Loss: 0.0182, Accuracy: 1.000
# [Epoch 5/15] Iteration 3080 -> Train Loss: 0.0678, Accuracy: 0.969
# [Epoch 5/15] Iteration 3090 -> Train Loss: 0.0693, Accuracy: 1.000
# [Epoch 5/15] Iteration 3100 -> Train Loss: 0.0654, Accuracy: 1.000
# [Epoch 5/15] Iteration 3110 -> Train Loss: 0.0379, Accuracy: 1.000
# [Epoch 5/15] Iteration 3120 -> Train Loss: 0.0776, Accuracy: 0.969
# [Epoch 5/15] Iteration 3130 -> Train Loss: 0.0346, Accuracy: 1.000
# [Epoch 5/15] Iteration 3140 -> Train Loss: 0.0178, Accuracy: 1.000
# [Epoch 5/15] Iteration 3150 -> Train Loss: 0.0337, Accuracy: 1.000
# [Epoch 5/15] Iteration 3160 -> Train Loss: 0.0281, Accuracy: 1.000
# [Epoch 5/15] Iteration 3170 -> Train Loss: 0.0273, Accuracy: 1.000
# [Epoch 5/15] Iteration 3180 -> Train Loss: 0.0435, Accuracy: 0.969
# [Epoch 5/15] Iteration 3190 -> Train Loss: 0.0310, Accuracy: 1.000
# [Epoch 5/15] Iteration 3200 -> Train Loss: 0.0214, Accuracy: 0.969
# [Epoch 5/15] Iteration 3210 -> Train Loss: 0.0267, Accuracy: 0.969
# [Epoch 5/15] Iteration 3220 -> Train Loss: 0.0407, Accuracy: 1.000
# [Epoch 5/15] Iteration 3230 -> Train Loss: 0.0330, Accuracy: 1.000
# [Epoch 5/15] Iteration 3240 -> Train Loss: 0.0276, Accuracy: 1.000
# [Epoch 5/15] Iteration 3250 -> Train Loss: 0.0432, Accuracy: 1.000
# [Epoch 5/15] Iteration 3260 -> Train Loss: 0.0266, Accuracy: 1.000
# [Epoch 5/15] Iteration 3270 -> Train Loss: 0.0299, Accuracy: 1.000
# [Epoch 5/15] Iteration 3280 -> Train Loss: 0.0325, Accuracy: 1.000
# [Epoch 5/15] Iteration 3290 -> Train Loss: 0.0147, Accuracy: 1.000
# [Epoch 5/15] Iteration 3300 -> Train Loss: 0.0678, Accuracy: 1.000
# [Epoch 5/15] Iteration 3310 -> Train Loss: 0.0256, Accuracy: 1.000
# [Epoch 5/15] Iteration 3320 -> Train Loss: 0.0340, Accuracy: 0.969
# [Epoch 5/15] Iteration 3330 -> Train Loss: 0.0231, Accuracy: 0.969
# [Epoch 5/15] Iteration 3340 -> Train Loss: 0.0270, Accuracy: 0.969
# [Epoch 5/15] Iteration 3350 -> Train Loss: 0.0222, Accuracy: 1.000
# [Epoch 5/15] Iteration 3360 -> Train Loss: 0.0418, Accuracy: 0.969
# [Epoch 5/15] Iteration 3370 -> Train Loss: 0.0771, Accuracy: 0.969
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-944e130dd4f2> in <module>()
#      14         loss.backward()
#      15         optimizer.step()
# ---> 16         total_loss += loss.item()
#      17         scheduler.step()
#      18
#
# KeyboardInterrupt:
